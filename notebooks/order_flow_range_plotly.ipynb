# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
renderer = 'png' # for interactive charts, change to plotly_mimetype or notebook

# %%
import pandas as pd
from order_flow_ticks import OrderFlowTicks

df_ticks = pd.read_parquet(f"data/US30_T1_2025_cT.parquet")
df_ticks.rename(columns={'bid': 'close'}, inplace=True)

df_ticks.head(3)
df_ticks.tail(3)
len(df_ticks)
# Out:
#                              ask    close  spread
# datetime
# 2025-05-15 00:00:00.650  41839.4  41838.3     1.1
# 2025-05-15 00:00:01.002  41839.8  41838.7     1.1
# 2025-05-15 00:00:01.252  41840.2  41839.1     1.1
#                              ask    close  spread
# datetime
# 2025-05-16 20:54:59.640  42376.7  42375.6     1.1
# 2025-05-16 20:54:59.841  42377.1  42376.0     1.1
# 2025-05-16 20:55:00.000  42377.9  42376.8     1.1
# 180399

# %%
from rangedf import Range
r = Range(df_ticks, range_size=20)
df_range = r.range_df()
df_range.head(3)
df_range.tail(3)
len(df_range)
# Out:
#                             open     high      low    close  volume
# datetime
# 2025-05-15 00:02:01.596  41840.3  41853.8  41833.8  41853.8   113.0
# 2025-05-15 00:24:42.996  41854.5  41872.5  41852.5  41872.5   542.0
# 2025-05-15 00:26:17.637  41872.6  41873.9  41853.9  41853.9    67.0
#                             open     high      low    close  volume
# datetime
# 2025-05-16 20:53:34.275  42435.6  42437.5  42417.5  42417.5    62.0
# 2025-05-16 20:54:10.439  42417.4  42424.5  42404.5  42404.5    81.0
# 2025-05-16 20:54:39.446  42403.4  42406.5  42386.5  42386.5    92.0
# 716

# %%
odft = OrderFlowTicks(df_range, df_ticks, 3, is_open_time=False)

# %%
odft.plot(iloc_value=20, chart='candle', renderer=renderer)

# %%
odft.plot(mode='buy_sell', view='divided', chart='ohlc', renderer=renderer)

# %%
odft.plot(mode='normal', chart='candle', renderer=renderer)

# %%
odft.plot(iloc_value=50, mode='normal', chart='candle', renderer=renderer)
